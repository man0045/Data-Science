# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y = np.sin(x)

# %%
plot = plt.plot(x,y)

# %%
plot

# %%
plot = plt.plot(x,y)
plt.xlabel("this is my x data")
plt.ylabel("this is my y data")
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y)

# %%
colours = np.random.rand(50)
sizes = np.random.rand(50)
plt.scatter(x,y,c = colours, s = sizes*40, alpha=1)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
x = ['a','b','c','d','e']

# %%
y = np.random.rand(5)
plt.barh(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Bar-plot")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\mannu\OneDrive\Desktop\Newfolder\pw datascience course\matplotlib.ipynb Cell 12 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/mannu/OneDrive/Desktop/Newfolder/pw%20datascience%20course/matplotlib.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> y = np.random.rand(5)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mannu/OneDrive/Desktop/Newfolder/pw%20datascience%20course/matplotlib.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> plt.barh(x,y)
#       <a href='vscode-notebook-cell:/c%3A/Users/mannu/OneDrive/Desktop/Newfolder/pw%20datascience%20course/matplotlib.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> plt.xlabel("X-axis")
#       <a href='vscode-notebook-cell:/c%3A/Users/mannu/OneDrive/Desktop/Newfolder/pw%20datascience%20course/matplotlib.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> plt.ylabel("Y-axis")
#
# ...

# %%
plt.ylabel("Y-axis")
plt.title("Bar-plot")

# %%
plot = plt.plot(x,y, '--b')
plt.figure(figsize = (8,4))
plt.xlabel("this is my x data")
plt.ylabel("this is my y data")
plt.title("this is my title")
plt.grid()
plt.show()

# %%
x = np.random.rand(50)
y  = np.random.rand(50)
colours = np.random.rand(50)
sizes = np.random.rand(50)
plt.scatter(x,y  ,c = 'b', s = 400*sizes, alpha = 0.5, marker = 'x')
plt.xlabel("x-axis")
plt.ylabel("y axis")
plt.title("random data")
# Out:
# Text(0.5, 1.0, 'random data')

# %%
x = [1,2,3,4,5,6]
y = [6,7,8,9,2,3]
plt.plot(x,y)
plt.show()

# %%
data = [1,2,3,4,5,6,7,8,9,1,2,3,]

# %%
plt.hist(data)
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [6,7,8,9,2,3]
colour = ['red', 'orange','green', 'violet', 'indigo', 'blue']
plt.scatter(x,y)
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z)
plt.show()
