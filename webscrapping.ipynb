# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipkart_url = "https://www.flipkart.com/search?q="+"realme9"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=realme9'

# %%
urlclient = urlopen(flipkart_url)

# %%
urlclient

# %%
flipcard_page = urlclient.read()

# %%
flipcard_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.4fb0ab.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
bs()

# %%
flipkart_html = bs(flipcard_page,'html.parser')

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
"https://www.flipkart.com/search?q="+"/apple-iphone-14-pro-max-space-black-128-gb/p/itm9aed88fe43457?pid=MOBGHWFHCNVGGMZF&lid=LSTMOBGHWFHCNVGGMZFEEIZN3&marketplace=FLIPKART&q=iphone+14+pro+max&store=tyy%2F4io&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_2_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_7_na_na_na&fm=organic&iid=03bd6a13-4a9d-4644-8d49-8964eecab157.MOBGHWFHCNVGGMZF.SEARCH&ppt=sp&ppn=sp&qH=549eba59c771754b"
# Out:
# 'https://www.flipkart.com/search?q=/apple-iphone-14-pro-max-space-black-128-gb/p/itm9aed88fe43457?pid=MOBGHWFHCNVGGMZF&lid=LSTMOBGHWFHCNVGGMZFEEIZN3&marketplace=FLIPKART&q=iphone+14+pro+max&store=tyy%2F4io&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_2_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_7_na_na_na&fm=organic&iid=03bd6a13-4a9d-4644-8d49-8964eecab157.MOBGHWFHCNVGGMZF.SEARCH&ppt=sp&ppn=sp&qH=549eba59c771754b'

# %%
bigbox = flipkart_html.findAll("div",{"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 30

# %%
del bigbox[0:3]

# %%
product_link = "https://www.flipkart.com" + bigbox[3].div.div.div.a['href']

# %%
product_req = requests.get(product_link)

# %%
product_html = bs(product_req.text, 'html.parser')

# %%
comment_box = product_html.findAll("div",{"class":"_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
for i in comment_box:
    print(i.div.div.find_all('p', {"class": "_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Sayan Naskar
# Sourav Das
# Flipkart Customer
# Smriti Das
# Mohammad Ashraf  Shamim
# Mayank Shrivastava
# Flipkart Customer
# Anmol Jalan
# YASH ROY
# Flipkart Customer
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\mannu\OneDrive\Desktop\Newfolder\pw datascience course\webscrapping.ipynb Cell 20 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/mannu/OneDrive/Desktop/Newfolder/pw%20datascience%20course/webscrapping.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> for i in comment_box:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mannu/OneDrive/Desktop/Newfolder/pw%20datascience%20course/webscrapping.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a>     print(i.div.div.find_all('p', {"class": "_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 4
# 5
# 5
# 5
# 5
# 5
# 4
# 4
# 4
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\mannu\OneDrive\Desktop\Newfolder\pw datascience course\webscrapping.ipynb Cell 21 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/mannu/OneDrive/Desktop/Newfolder/pw%20datascience%20course/webscrapping.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> for i in comment_box:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mannu/OneDrive/Desktop/Newfolder/pw%20datascience%20course/webscrapping.ipynb#X41sZmlsZQ%3D%3D?line=1'>2</a>     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comment_box:
    print(i.div.div.div.p.text)
# Out:
# Delightful
# Terrific purchase
# Terrific purchase
# Fabulous!
# Simply awesome
# Mind-blowing purchase
# Good quality product
# Good quality product
# Delightful
# Wonderful
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\mannu\OneDrive\Desktop\Newfolder\pw datascience course\webscrapping.ipynb Cell 22 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/mannu/OneDrive/Desktop/Newfolder/pw%20datascience%20course/webscrapping.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> for i in comment_box:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mannu/OneDrive/Desktop/Newfolder/pw%20datascience%20course/webscrapping.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a>     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.find_all('div', {"class":''})
# Out:
# [<div><div class="">A great phone in this segment...... The camera is better than decent, 108mp allows you to capture more details... Manual control for camera is quite good..... Display is like flagship level, great in outdoor.... Gaming performance is not that good slightly less than decent..... A good choice Daily performance or daily task usage... Best phone for students like me I'll say... If you want a phone which can handle multitasking, with a good camera,decent gaming, and best display... Go for it... A...</div><span class="_1BWGvX"><span>READ MORE</span></span></div>,
# ...

# %%
for i in comment_box:
    print(i.div.div.find_all('div', {"class":''})[0].div.text)
# Out:
# A great phone in this segment...... The camera is better than decent, 108mp allows you to capture more details... Manual control for camera is quite good..... Display is like flagship level, great in outdoor.... Gaming performance is not that good slightly less than decent..... A good choice Daily performance or daily task usage... Best phone for students like me I'll say... If you want a phone which can handle multitasking, with a good camera,decent gaming, and best display... Go for it... A...
# Overall very good mobileGood camera best display smooth ui and very good battery backup
# Its a great mobile at current time in this budget..What a display it is! Such a marvelous quality...I love so much 🤩🤩
# ...

# %% [markdown]
# for i in bigbox:
#     print("https://www.flipkart.com" + i.div.div.div.a['href'])
